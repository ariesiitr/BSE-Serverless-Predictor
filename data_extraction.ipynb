# %% [markdown]
# ### Common Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date
from datetime import timedelta

# %% [markdown]
# ### Quandl

# %% [markdown]
# Using Quandl to get free historical data

# %% [markdown]
# !pip install quandl

# %%
# !pip install quandl
import quandl
quandl.ApiConfig.api_key = 'U4m2As16aHLxEiSQtGvn'## API Key provided after creating free ID on Quaqndl
quandl.save_key("U4m2As16aHLxEiSQtGvn")

# %% [markdown]
# ### Getting Quandl Codes
# This downloads a folder named Quandl Codes in working directory.

# %%
import requests, zipfile, io
r = requests.get('https://www.quandl.com/api/v3/databases/BSE/metadata?api_key=U4m2As16aHLxEiSQtGvn')
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall("data/Quandl_Codes")
quandl_codes=pd.read_csv('data/Quandl_Codes/BSE_metadata.csv')
quandl_codes
# Out:
#            code                                              name  \
# 0     BOM500002                      ABB India Limited EOD Prices
# 1     BOM500003                   AEGIS LOGISTICS LTD. EOD Prices
# 2     BOM500008              AMARA RAJA BATTERIES LTD. EOD Prices
# 3     BOM500009      AMBALAL SARABHAI ENTERPRISES LTD. EOD Prices
# 4     BOM500010  HOUSING DEVELOPMENT FINANCE CORP.LTD. EOD Prices
# ...         ...                                               ...
# 5116   SPBSS5IP                                     BSE SENSEX 50
# 5117   SPBSSSIP                         BSE SmallCap Select Index
# 5118   SPBSTLIP                                       BSE Telecom
# 5119   SPBSUTIP                                     BSE Utilities
# 5120   SPICBLOT                             BSE Liquid Rate Index
#
#                                             description         refreshed_at  \
# 0     End of Day prices and additional trading infor...  2021-05-04 14:15:43
# ...

# %%
close=pd.DataFrame()
columns_list=[];
for row,company in quandl_codes.iterrows():
    if(company['to_date']==str(date.today()-timedelta(days=1))):
        data=quandl.get('BSE/'+company['code'],start_date="2010-01-01")
        company_name=company['name']
        close[company_name]=data['Close']
        columns_list.append(company_name)
        #data.to_excel('data/'+company_name+'.xlsx')
        close.to_excel('data/close.xlsx')

# %%
data1=quandl.get('BSE/BOM500002',start_date='1992/03/05')
data2=quandl.get('BSE/BOM500003',start_date='1992/03/05')

# %%
data1
# Out:
#               Open     High     Low    Close      WAP  No. of Shares  \
# Date
# 1992-03-10   610.0   650.00   550.0   650.00     0.00            0.0
# 1992-03-11   550.0   600.00   500.0   600.00     0.00            0.0
# 1992-03-12   500.0   550.00   500.0   550.00     0.00            0.0
# 1992-03-13   500.0   575.00   475.0   550.00     0.00            0.0
# 1992-03-17   600.0   600.00   550.0   600.00     0.00            0.0
# ...            ...      ...     ...      ...      ...            ...
# 2021-04-28  1412.5  1440.00  1360.3  1382.80  1399.06        22546.0
# 2021-04-29  1407.0  1407.00  1378.1  1383.15  1387.26         5008.0
# 2021-04-30  1382.0  1399.00  1362.3  1382.75  1377.58        11122.0
# 2021-05-03  1389.0  1398.00  1352.8  1393.45  1384.79        20428.0
# 2021-05-04  1370.0  1398.85  1366.0  1375.00  1390.58         6668.0
#
#             No. of Trades  Total Turnover  Deliverable Quantity  \
# Date
# ...

# %%
data_append=data1[['Close']]
data_append.columns=["ABB India Limited EOD Prices"]
data_append.head(5)
# Out:
#             ABB India Limited EOD Prices
# Date
# 1992-03-10                         650.0
# 1992-03-11                         600.0
# 1992-03-12                         550.0
# 1992-03-13                         550.0
# 1992-03-17                         600.0

# %%
quandl_codes
# Out:
#            code                                              name  \
# 0     BOM500002                      ABB India Limited EOD Prices
# 1     BOM500003                   AEGIS LOGISTICS LTD. EOD Prices
# 2     BOM500008              AMARA RAJA BATTERIES LTD. EOD Prices
# 3     BOM500009      AMBALAL SARABHAI ENTERPRISES LTD. EOD Prices
# 4     BOM500010  HOUSING DEVELOPMENT FINANCE CORP.LTD. EOD Prices
# ...         ...                                               ...
# 5116   SPBSS5IP                                     BSE SENSEX 50
# 5117   SPBSSSIP                         BSE SmallCap Select Index
# 5118   SPBSTLIP                                       BSE Telecom
# 5119   SPBSUTIP                                     BSE Utilities
# 5120   SPICBLOT                             BSE Liquid Rate Index
#
#                                             description         refreshed_at  \
# 0     End of Day prices and additional trading infor...  2021-05-04 14:15:43
# ...

# %%
data=data2[['Close']]
data.columns=['AEGIS LOGISTICS LTD']
data.head(5)
# Out:
#             AEGIS LOGISTICS LTD
# Date
# 1992-03-10                 47.5
# 1992-03-11                 47.5
# 1992-03-12                 47.5
# 1992-03-13                 47.5
# 1992-03-17                 55.0

# %%
final_data=pd.concat([data,data_append],axis=1)
final_data
# Out:
#             AEGIS LOGISTICS LTD  ABB India Limited EOD Prices
# Date
# 1992-03-10                47.50                        650.00
# 1992-03-11                47.50                        600.00
# 1992-03-12                47.50                        550.00
# 1992-03-13                47.50                        550.00
# 1992-03-17                55.00                        600.00
# ...                         ...                           ...
# 2021-04-28               313.55                       1382.80
# 2021-04-29               308.45                       1383.15
# 2021-04-30               304.10                       1382.75
# 2021-05-03               313.00                       1393.45
# 2021-05-04               323.70                       1375.00
#
# [6264 rows x 2 columns]

# %%
final_data.to_excel('data/test_aws.xlsx')

# %%
final_data=pd.DataFrame([data1['Close'],data2['Close']]).T

# %%
pd.DataFrame(data1['Close'])
# Out:
#               Close
# Date
# 1992-03-02   575.00
# 1992-03-03   625.00
# 1992-03-10   650.00
# 1992-03-11   600.00
# 1992-03-12   550.00
# ...             ...
# 2021-02-01  1380.90
# 2021-02-02  1442.65
# 2021-02-03  1443.00
# 2021-02-04  1517.50
# 2021-02-05  1495.00
#
# [6209 rows x 1 columns]

# %%
final_data.head(5)
# Out:
#             Close  Close
# Date
# 1992-03-02  575.0    NaN
# 1992-03-03  625.0    NaN
# 1992-03-10  650.0   47.5
# 1992-03-11  600.0   47.5
# 1992-03-12  550.0   47.5

# %%
data1
# Out:
#                Open    High      Low    Close      WAP  No. of Shares  \
# Date
# 1992-03-02   525.00   600.0   525.00   575.00     0.00            0.0
# 1992-03-03   575.00   670.0   575.00   625.00     0.00            0.0
# 1992-03-10   610.00   650.0   550.00   650.00     0.00            0.0
# 1992-03-11   550.00   600.0   500.00   600.00     0.00            0.0
# 1992-03-12   500.00   550.0   500.00   550.00     0.00            0.0
# ...             ...     ...      ...      ...      ...            ...
# 2021-02-01  1400.00  1400.0  1359.70  1380.90  1382.76         4824.0
# 2021-02-02  1397.45  1507.0  1397.45  1442.65  1443.76        20663.0
# 2021-02-03  1479.00  1479.0  1403.30  1443.00  1435.39        16509.0
# 2021-02-04  1445.05  1533.9  1444.80  1517.50  1509.80        22745.0
# 2021-02-05  1516.00  1521.3  1483.50  1495.00  1499.81         8209.0
#
#             No. of Trades  Total Turnover  Deliverable Quantity  \
# Date
# ...

# %%
data2
# Out:
#               Open    High     Low   Close     WAP  No. of Shares  \
# Date
# 1992-03-02   50.00   57.50   50.00   55.00    0.00            0.0
# 1992-03-03   47.50   53.75   47.50   52.50    0.00            0.0
# 1992-03-10   45.00   50.00   45.00   47.50    0.00            0.0
# 1992-03-11   45.00   47.50   45.00   47.50    0.00            0.0
# 1992-03-12   45.00   47.50   45.00   47.50    0.00            0.0
# ...            ...     ...     ...     ...     ...            ...
# 2021-02-01  283.30  287.00  277.50  283.50  282.94         3844.0
# 2021-02-02  285.00  292.00  280.40  280.85  285.88         7647.0
# 2021-02-03  281.65  315.05  281.65  292.20  298.23       104151.0
# 2021-02-04  293.00  296.15  288.85  294.75  293.50        11238.0
# 2021-02-05  296.00  302.00  293.50  294.55  297.21         8473.0
#
#             No. of Trades  Total Turnover  Deliverable Quantity  \
# Date
# 1992-03-02            0.0             0.0                   NaN
# ...

# %%
from bsedata.bse import BSE
bsedata = BSE()

# to execute "updateScripCodes" on instantiation
bsedata = BSE(update_codes = True)

import pandas as pd
from bselib.bse import BSE
bselib = BSE()

# %%
cnt=0
price={}
for company in bsedata.getScripCodes():
    try:
        q=bselib.quote(company)["stockPrice"]
        price[company]=q
        print(company,cnt)
        cnt=cnt+1
    except:
        continue
# Out:
# 533022 0
# 532628 1
# 523395 2
# 590116 3
# 512161 4
# 538351 5
# 539300 6
# 530499 7
# 533292 8
# 531611 9

# %%
list(price)
# Out:
# ['533022',
#  '532628',
#  '523395',
#  '590116',
#  '512161',
#  '538351',
#  '539300',
#  '530499',
#  '533292',
#  '531611']

# %%
close=pd.DataFrame(list(price.items()),columns = ["Company_Code",'Price'])
close.to_excel("close.xlsx")

# %%
close=pd.DataFrame([date.today()]+price).T
close
# Out:
#          0      1     2         3      4      5      6      7       8     \
# 0  2021-03-28  34.50  7.42  28816.50  14.94  79.85  15.50  26.50  316.70
#
#    9     ...    4335  4336   4337  4338   4339   4340   4341  4342     4343  \
# 0  3.80  ...  278.80  1.68  95.95  3.80  25.90  86.00  79.80  0.87  1962.35
#
#    4344
# 0  0.67
#
# [1 rows x 4345 columns]

# %%
from numpy import save
len(company_code)
len(price)
save('company_code.npy',company_code)
save('price.npy',price)

# %%
close={}
columns_list=[];
for company in b.getScripCodes():
    print(company)
    close_price=b.getQuote(company)["currentValue"]
    company_code=company
    close[company_code]=close_price
# Out:
# 533022
# 532628
# 523395
# 590116
# 512161
# 538351
# 539300
# 530499
# 533292
# 531611
# 530027
# 531866
# 539096
# 538812
# 524412
# 524348
# 524208
# 514274
# 531731
# 519319
# 512038
# 523204
# 512165
# 500002
# 500488
# 505665
# 513119
# 520123
# 532682
# 532057
# 538952
# 532831
# 538935
# 511756
# 526955
# 531161
# 500410
# 532774
# 517494
# 532268
# 531897
# 526347
# 530513
# 530093
# 531525
# 536492
# 538570
# 517356
# 530901
# 530043
# 539391
# 533330
# 513149
# 524091
# 532762
# 511706
# 511359
# 512599
# 532921
# 533096
# 539254
# 538563
# 526711
# 523411
# 538734
# 507852
# 519183
# 539189
# 538365
# 532727
# 530117
# 531592
# 590088
# 532056
# 514113
# 500057
# 535755
# 532974
# 500303
# 522150
# 513513
# 521141
# 539056
# 530431
# 523120
# 517041
# 523031
# 521048
# 534612
# 506947
# 531047
# 517552
# 523269
# 532840
# 531429
# 531686
# 500003
# 530707
# 531921
# 500463
# 539042
# 516020
# 537292
# 537492
# 519281
# 500215
# 524448
# 532811
# 522273
# 532806
# 532683
# ...

# %%
import pandas as pd
b.getQuote(506120)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-84ce047ff9a8> in <module>
# ----> 1 import pandas as pd
#       2 b.getQuote(506120)
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in <module>
#     175
#     176 from pandas.util._tester import test
# --> 177 import pandas.testing
#     178 import pandas.arrays
#     179
#
# ~\anaconda3\lib\site-packages\pandas\testing.py in <module>
#       3 """
#       4
# ----> 5 from pandas._testing import (
#       6     assert_extension_array_equal,
#       7     assert_frame_equal,
#
# ~\anaconda3\lib\site-packages\pandas\_testing.py in <module>
#    2904
#    2905
# -> 2906 cython_table = pd.core.base.SelectionMixin._cython_table.items()
#    2907
#    2908
#
# AttributeError: partially initialized module 'pandas' has no attribute 'core' (most likely due to a circular import)

# %%
import pandas as pd
from bselib.bse import BSE
b = BSE()
print(b)
# Out:
# Driver Class for Bombay Stock Exchange

# %%
b.quote('506120')['previousClose']
# Out:
# '28.95'

# %%
bselib.quote(522275)['info']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-24bf8d5e9ddf> in <module>
# ----> 1 bselib.quote(522275)['info']
#
# KeyError: 'info'

# %%
from numpy import load

# %%
data=load('price.npy')

# %%
len(data)
# Out:
# 4344

# %%
import pandas as pd
close=pd.read_excel("data/close.xlsx",index_col="Company_Code")
close.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
close=close.T

# %%
date=(date.today()-timedelta(days=3))
date
# Out:
# datetime.date(2021, 3, 26)

# %%
close=close.rename({"Price":date},axis='index')

# %%
close
# Out:
# Company_Code 533022 532628    523395 590116 512161 538351 539300  530499  \
# 2021-03-26    34.50   7.42  28816.50  14.94  79.85  15.50  26.50  316.70
#
# Company_Code 533292 531611  ...  504067 531404 521163 503641 512587 534742  \
# 2021-03-26     3.80   0.49  ...  278.80   1.68  95.95   3.80  25.90  86.00
#
# Company_Code 500780 530091   531335 532883
# 2021-03-26    79.80   0.87  1962.35   0.67
#
# [1 rows x 4344 columns]

# %%
close.to_excel("data/close_s3_input.xlsx")

# %%
bselib.quote(530499)
# Out:
# {'stockName': 'A.K.CAPITAL SERVICES LTD.',
#  'stockPrice': '316.70',
#  'change': '--5.05',
#  'pChange': '--1.57',
#  'ltd': 'LTD- 26 Mar 21 | 04:00 PM',
#  'securityId': 'AKCAPIT',
#  'scriptCode': '530499',
#  'group': 'X',
#  'index': '',
#  'faceValue': '10.00',
#  'previousClose': '321.75',
#  'lastOpen': '324.00',
#  'daysHigh': '329.80',
#  'daysLow': '314.00',
#  'wtdAvgPrice': '316.72',
#  'totalTradedValue': {'in': 'Cr', 'value': '0.04'},
#  'totalTradedQty': {'in': 'Lac', 'value': '0.01'},
#  'twoWeekAvgQty': {'in': 'Lac', 'value': '0.06'},
#  'mktCap': {'in': 'Cr', 'value': '209.02'},
#  'freeFloat': {'in': 'Cr', 'value': '62.71'},
#  'fiftytwo_WeekHigh': 399.0,
#  'fiftytwo_WeekLow': 163.3,
#  'monthHighLow': '399.00 / 312.05'}

# %%
news = b.news(500325)

# %%
news
# Out:
# {'news': [{'newsid': '33779c2e86447b43acbe4115f26f4d12',
#    'category': '',
#    'description': 'Stocks to Watch: RIL, Adani Ports and SEZ, ICICI Bank, Bajaj Auto  Mint',
#    'imagepath': '',
#    'link': 'https://www.livemint.com/market/stock-market-news/stocks-to-watch-ril-adani-ports-and-sez-icici-bank-bajaj-auto-11620091949109.html',
#    'newstype': 'STKNWS',
#    'publisheddate': '04-May-2021 07:30',
#    'source': 'https://www.livemint.com',
#    'stockid': 605152,
#    'title': 'Stocks to Watch: RIL, Adani Ports and SEZ, ICICI Bank, Bajaj Auto'},
#   {'newsid': '64faa955f7c6a2c3ed531a2ba413481d',
# ...
